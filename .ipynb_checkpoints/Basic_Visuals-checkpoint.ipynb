# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
data = np.loadtxt('./data/data.txt').astype(int)

# %%
# Get some basic counts for later use
n_movies = 1682
num_ratings = [0 for i in range(n_movies)]
avg_ratings = [0 for i in range(n_movies)]

for rating in data:
    movie_ind = rating[1] - 1
    num_ratings[movie_ind] += 1
    avg_ratings[movie_ind] += rating[2]
    
for i in range(n_movies):
    avg_ratings[i] /= num_ratings[i]

# %%
# Visualization 1 - All ratings
ratings = [0 for i in range(5)]
for rating in data:
    rating_ind = rating[2] - 1
    ratings[rating_ind] += 1
    
rating_values = [i+1 for i in range(5)]
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.bar(rating_values, ratings)
plt.title('All ratings')
plt.xlabel('Rating Value')
plt.ylabel('Number of ratings')
plt.show()
plt.savefig('All_ratings.png')

# %%
# Visualization 2 - Ratings of most popular movies
most_rated = np.argpartition(num_ratings, -10)[-10:]

ratings = [0 for i in range(5)]
for rating in data:
    movie_ind = rating[1] - 1
    if movie_ind in most_rated:
        rating_ind = rating[2] - 1
        ratings[rating_ind] += 1

rating_values = [i+1 for i in range(5)]
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.bar(rating_values, ratings)
plt.title('Ratings of most popular movies')
plt.xlabel('Rating')
plt.ylabel('Number of ratings')
plt.show()
plt.savefig('Popular_ratings.png')

# %%
# Visualization 3 - Ratings of most popular movies
high_rated = np.argpartition(avg_ratings, -10)[-10:]

ratings = [0 for i in range(5)]
for rating in data:
    movie_ind = rating[1] - 1
    if movie_ind in high_rated:
        rating_ind = rating[2] - 1
        ratings[rating_ind] += 1

rating_values = [i+1 for i in range(5)]
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.bar(rating_values, ratings)
plt.title('Ratings of best rated movies')
plt.xlabel('Rating')
plt.ylabel('Number of ratings')
plt.show()
plt.savefig('Best_ratings.png')

# %%
# Loading the movie data
movie_data = np.genfromtxt('./data/movies.txt', dtype=None, delimiter='\t', encoding='utf8')

# %%
# Get the movie ids for three genres
action_movies = []
comedy_movies = []
crime_movies = []
for movie in movie_data:
    if movie[3] == 1:
        action_movies.append(movie[0])
    if movie[7] == 1:
        comedy_movies.append(movie[0])
    if movie[8] == 1:
        crime_movies.append(movie[0])

# %%
# Visualizations for 3 - Action movies

ratings = [0 for i in range(5)]
for rating in data:
    movie_ind = rating[1]
    if movie_ind in action_movies:
        rating_ind = rating[2] - 1
        ratings[rating_ind] += 1

rating_values = [i+1 for i in range(5)]
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.bar(rating_values, ratings)
plt.title('Ratings of Action movies')
plt.xlabel('Rating')
plt.ylabel('Number of ratings')
plt.show()
plt.savefig('Action_ratings.png')

# %%
# Visualizations for 3 - Comedy movies

ratings = [0 for i in range(5)]
for rating in data:
    movie_ind = rating[1]
    if movie_ind in comedy_movies:
        rating_ind = rating[2] - 1
        ratings[rating_ind] += 1

rating_values = [i+1 for i in range(5)]
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.bar(rating_values, ratings)
plt.title('Ratings of Comedy movies')
plt.xlabel('Rating')
plt.ylabel('Number of ratings')
plt.show()
plt.savefig('Comedy_ratings.png')

# %%
# Visualizations for 3 - Crime movies

ratings = [0 for i in range(5)]
for rating in data:
    movie_ind = rating[1]
    if movie_ind in crime_movies:
        rating_ind = rating[2] - 1
        ratings[rating_ind] += 1

rating_values = [i+1 for i in range(5)]
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.bar(rating_values, ratings)
plt.title('Ratings of Crime movies')
plt.xlabel('Rating')
plt.ylabel('Number of ratings')
plt.show()
plt.savefig('Crime_ratings.png')
